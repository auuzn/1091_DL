# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import np_utils
from keras.datasets import cifar10

(x_train_image, y_train_label), (x_test_image, y_test_label) = cifar10.load_data()
class_names = ['airplain', 'automobile', ' bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


def plot_multiimages(images, labels, prediction, idx, num=32):
    plt.gcf().set_size_inches(14, 4)
    if num > 32: num = 32
    for i in range(0, num):
        ax = plt.subplot(4, 8, 1 + i)
        ax.imshow(images[idx], cmap='rainbow')
        title = "l=" + class_names[int(labels[idx])]
        if len(prediction) > 0:
            title = "l={},p={}".format(class_names[int(labels[idx])], class_names[prediction[idx]])
        else:
            title = "l={}".format(class_names[int(labels[idx])])
        ax.set_title(title, fontsize=8)
        ax.set_xticks([])
        ax.set_yticks([])
        idx += 1

    plt.tight_layout()
    plt.show()


x_train = x_train_image.reshape(len(x_train_image), 32, 32, 3).astype('float32')
x_test = x_test_image.reshape(len(x_test_image), 32, 32, 3).astype('float32')
x_train_norm = x_train / 255
x_test_norm = x_test / 255
y_TrainOneHot = np_utils.to_categorical(y_train_label)
y_TestOneHot = np_utils.to_categorical(y_test_label)


from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv1D, Conv2D, MaxPooling2D

model = Sequential()  # Build Linear Model

model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), padding='same',activation='relu'))
model.add(Conv2D(128, (3, 3), padding='same',activation='relu'))
model.add(MaxPooling2D((2, 2)))
# model.add(Conv2D(256, (3, 3), padding='same',activation='relu'))
# model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(256, (3, 3), padding='same',activation='relu'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
train_history = model.fit(x=x_train_norm[0:5000], y=y_TrainOneHot[0:5000], validation_split=0.2, epochs=5,
                          batch_size=20, verbose=2)


def show_train_history(train_history, train, validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()


show_train_history(train_history, 'accuracy', 'val_accuracy')
show_train_history(train_history, 'loss', 'val_loss')

scores = model.evaluate(x_test_norm, y_TestOneHot)
print()
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1] * 100.0))
print("\t[Info] Making prediction to x_test_norm")

prediction = model.predict_classes(x_test_norm[0:1000])  # Making prediction and save result to prediction
# classes = np.argmax(prediction, axis=-1)
print()
print("\t[Info] Show 10 prediction result (From 0):")
print("%s\n" % (prediction[0:10]))
plot_multiimages(x_test_image, y_test_label, prediction, idx=0)

print("\t[Info] Error analysis:")
for i in range(len(prediction)):
    if prediction[i] != y_test_label[i]:
        print("\tAt %d'th: %d is with wrong prediction as %d!" % (i, y_test_label[i], prediction[i]))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 2,425,930
# Trainable params: 2,425,930
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 200/200 - 28s - loss: 2.2428 - accuracy: 0.1497 - val_loss: 2.0928 - val_accuracy: 0.2190
# Epoch 2/5
# 200/200 - 28s - loss: 2.0340 - accuracy: 0.2212 - val_loss: 1.7830 - val_accuracy: 0.3300
# Epoch 3/5
# 200/200 - 27s - loss: 1.8704 - accuracy: 0.2952 - val_loss: 1.7010 - val_accuracy: 0.3810
# Epoch 4/5
# 200/200 - 28s - loss: 1.7062 - accuracy: 0.3575 - val_loss: 1.8077 - val_accuracy: 0.3550
# Epoch 5/5
# 200/200 - 28s - loss: 1.6212 - accuracy: 0.3910 - val_loss: 1.5150 - val_accuracy: 0.4630
# 313/313 [==============================] - 19s 60ms/step - loss: 1.4987 - accuracy: 0.4518
#
# 	[Info] Accuracy of testing data = 45.2%
# 	[Info] Making prediction to x_test_norm
# WARNING:tensorflow:From <ipython-input-6-3f50a3fa98ae>:92: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#
# 	[Info] Show 10 prediction result (From 0):
# [3 8 8 8 4 6 1 2 5 1]
# 	[Info] Error analysis:
# 	At 3'th: 0 is with wrong prediction as 8!
# 	At 4'th: 6 is with wrong prediction as 4!
# 	At 7'th: 6 is with wrong prediction as 2!
# 	At 8'th: 3 is with wrong prediction as 5!
# 	At 10'th: 0 is with wrong prediction as 2!
# 	At 14'th: 9 is with wrong prediction as 1!
# 	At 15'th: 8 is with wrong prediction as 0!
# 	At 17'th: 7 is with wrong prediction as 9!
# 	At 20'th: 7 is with wrong prediction as 5!
# 	At 22'th: 4 is with wrong prediction as 2!
# 	At 23'th: 9 is with wrong prediction as 1!
# 	At 24'th: 5 is with wrong prediction as 2!
# 	At 25'th: 2 is with wrong prediction as 6!
# 	At 27'th: 0 is with wrong prediction as 7!
# 	At 28'th: 9 is with wrong prediction as 1!
# 	At 31'th: 5 is with wrong prediction as 4!
# 	At 32'th: 4 is with wrong prediction as 2!
# 	At 33'th: 5 is with wrong prediction as 6!
# 	At 35'th: 2 is with wrong prediction as 5!
# 	At 38'th: 9 is with wrong prediction as 1!
# 	At 40'th: 4 is with wrong prediction as 9!
# 	At 42'th: 5 is with wrong prediction as 7!
# 	At 44'th: 0 is with wrong prediction as 8!
# 	At 47'th: 9 is with wrong prediction as 0!
# 	At 48'th: 7 is with wrong prediction as 4!
# 	At 49'th: 6 is with wrong prediction as 4!
# 	At 52'th: 0 is with wrong prediction as 6!
# 	At 53'th: 3 is with wrong prediction as 6!
# 	At 56'th: 7 is with wrong prediction as 5!
# 	At 57'th: 7 is with wrong prediction as 1!
# 	At 58'th: 4 is with wrong prediction as 3!
# 	At 59'th: 6 is with wrong prediction as 5!
# 	At 60'th: 7 is with wrong prediction as 4!
# 	At 61'th: 3 is with wrong prediction as 6!
# 	At 63'th: 3 is with wrong prediction as 5!
# 	At 65'th: 2 is with wrong prediction as 5!
# 	At 67'th: 2 is with wrong prediction as 0!
# 	At 68'th: 3 is with wrong prediction as 5!
# 	At 71'th: 6 is with wrong prediction as 7!
# 	At 74'th: 0 is with wrong prediction as 9!
# 	At 75'th: 2 is with wrong prediction as 4!
# 	At 76'th: 9 is with wrong prediction as 8!
# 	At 77'th: 3 is with wrong prediction as 5!
# 	At 78'th: 3 is with wrong prediction as 5!
# 	At 83'th: 7 is with wrong prediction as 5!
# 	At 85'th: 5 is with wrong prediction as 7!
# 	At 86'th: 2 is with wrong prediction as 5!
# 	At 87'th: 7 is with wrong prediction as 8!
# 	At 89'th: 9 is with wrong prediction as 1!
# 	At 90'th: 0 is with wrong prediction as 8!
# 	At 91'th: 3 is with wrong prediction as 4!
# 	At 95'th: 6 is with wrong prediction as 7!
# 	At 98'th: 0 is with wrong prediction as 5!
# 	At 100'th: 4 is with wrong prediction as 2!
# 	At 101'th: 5 is with wrong prediction as 2!
# 	At 105'th: 1 is with wrong prediction as 8!
# 	At 106'th: 3 is with wrong prediction as 6!
# 	At 108'th: 8 is with wrong prediction as 5!
# 	At 109'th: 7 is with wrong prediction as 5!
# 	At 110'th: 4 is with wrong prediction as 6!
# 	At 112'th: 6 is with wrong prediction as 4!
# 	At 115'th: 3 is with wrong prediction as 7!
# 	At 117'th: 4 is with wrong prediction as 7!
# 	At 118'th: 2 is with wrong prediction as 4!
# 	At 119'th: 7 is with wrong prediction as 5!
# 	At 121'th: 3 is with wrong prediction as 2!
# 	At 123'th: 2 is with wrong prediction as 4!
# 	At 125'th: 0 is with wrong prediction as 5!
# 	At 126'th: 8 is with wrong prediction as 3!
# 	At 127'th: 3 is with wrong prediction as 5!
# 	At 128'th: 5 is with wrong prediction as 3!
# 	At 134'th: 1 is with wrong prediction as 5!
# 	At 135'th: 2 is with wrong prediction as 5!
# 	At 136'th: 9 is with wrong prediction as 1!
# 	At 137'th: 7 is with wrong prediction as 0!
# 	At 138'th: 2 is with wrong prediction as 4!
# 	At 139'th: 9 is with wrong prediction as 8!
# 	At 140'th: 6 is with wrong prediction as 4!
# 	At 142'th: 6 is with wrong prediction as 3!
# 	At 143'th: 3 is with wrong prediction as 5!
# 	At 147'th: 2 is with wrong prediction as 5!
# 	At 149'th: 2 is with wrong prediction as 5!
# 	At 151'th: 9 is with wrong prediction as 1!
# 	At 152'th: 6 is with wrong prediction as 3!
# 	At 154'th: 0 is with wrong prediction as 2!
# 	At 158'th: 5 is with wrong prediction as 6!
# 	At 159'th: 4 is with wrong prediction as 0!
# 	At 160'th: 2 is with wrong prediction as 5!
# 	At 162'th: 6 is with wrong prediction as 1!
# 	At 165'th: 4 is with wrong prediction as 7!
# 	At 168'th: 5 is with wrong prediction as 7!
# 	At 169'th: 0 is with wrong prediction as 9!
# 	At 172'th: 9 is with wrong prediction as 8!
# 	At 176'th: 3 is with wrong prediction as 2!
# 	At 179'th: 0 is with wrong prediction as 8!
# 	At 180'th: 0 is with wrong prediction as 8!
# 	At 181'th: 5 is with wrong prediction as 7!
# 	At 182'th: 2 is with wrong prediction as 4!
# 	At 184'th: 3 is with wrong prediction as 7!
# 	At 186'th: 6 is with wrong prediction as 4!
# 	At 188'th: 4 is with wrong prediction as 7!
# 	At 189'th: 0 is with wrong prediction as 8!
# 	At 190'th: 5 is with wrong prediction as 4!
# 	At 191'th: 8 is with wrong prediction as 1!
# 	At 192'th: 0 is with wrong prediction as 1!
# 	At 195'th: 2 is with wrong prediction as 4!
# 	At 196'th: 8 is with wrong prediction as 1!
# 	At 197'th: 8 is with wrong prediction as 2!
# 	At 200'th: 5 is with wrong prediction as 7!
# 	At 201'th: 1 is with wrong prediction as 9!
# 	At 203'th: 7 is with wrong prediction as 8!
# 	At 205'th: 3 is with wrong prediction as 2!
# 	At 208'th: 7 is with wrong prediction as 4!
# 	At 209'th: 9 is with wrong prediction as 8!
# 	At 210'th: 7 is with wrong prediction as 5!
# 	At 211'th: 4 is with wrong prediction as 9!
# 	At 213'th: 9 is with wrong prediction as 7!
# 	At 215'th: 0 is with wrong prediction as 2!
# 	At 218'th: 8 is with wrong prediction as 0!
# 	At 219'th: 2 is with wrong prediction as 7!
# 	At 220'th: 7 is with wrong prediction as 5!
# 	At 221'th: 6 is with wrong prediction as 5!
# 	At 222'th: 9 is with wrong prediction as 1!
# 	At 223'th: 4 is with wrong prediction as 5!
# 	At 224'th: 3 is with wrong prediction as 7!
# 	At 227'th: 4 is with wrong prediction as 5!
# 	At 228'th: 7 is with wrong prediction as 2!
# 	At 229'th: 6 is with wrong prediction as 5!
# 	At 233'th: 8 is with wrong prediction as 1!
# 	At 237'th: 0 is with wrong prediction as 9!
# 	At 242'th: 8 is with wrong prediction as 0!
# 	At 245'th: 3 is with wrong prediction as 5!
# 	At 247'th: 9 is with wrong prediction as 0!
# 	At 248'th: 2 is with wrong prediction as 5!
# 	At 249'th: 2 is with wrong prediction as 1!
# 	At 250'th: 5 is with wrong prediction as 7!
# 	At 251'th: 3 is with wrong prediction as 5!
# 	At 253'th: 9 is with wrong prediction as 1!
# 	At 255'th: 0 is with wrong prediction as 2!
# 	At 256'th: 3 is with wrong prediction as 6!
# 	At 257'th: 0 is with wrong prediction as 1!
# 	At 258'th: 0 is with wrong prediction as 8!
# 	At 259'th: 9 is with wrong prediction as 1!
# 	At 260'th: 8 is with wrong prediction as 1!
# 	At 262'th: 5 is with wrong prediction as 6!
# 	At 263'th: 7 is with wrong prediction as 3!
# 	At 266'th: 2 is with wrong prediction as 5!
# 	At 267'th: 4 is with wrong prediction as 6!
# 	At 269'th: 0 is with wrong prediction as 2!
# 	At 271'th: 3 is with wrong prediction as 5!
# 	At 273'th: 3 is with wrong prediction as 5!
# 	At 276'th: 0 is with wrong prediction as 8!
# 	At 277'th: 3 is with wrong prediction as 7!
# 	At 279'th: 3 is with wrong prediction as 5!
# 	At 280'th: 9 is with wrong prediction as 8!
# 	At 281'th: 0 is with wrong prediction as 1!
# 	At 282'th: 6 is with wrong prediction as 3!
# 	At 284'th: 0 is with wrong prediction as 8!
# 	At 287'th: 0 is with wrong prediction as 8!
# 	At 288'th: 7 is with wrong prediction as 8!
# 	At 291'th: 2 is with wrong prediction as 4!
# 	At 293'th: 9 is with wrong prediction as 1!
# 	At 294'th: 3 is with wrong prediction as 5!
# 	At 297'th: 0 is with wrong prediction as 8!
# 	At 302'th: 3 is with wrong prediction as 7!
# 	At 303'th: 2 is with wrong prediction as 5!
# 	At 304'th: 6 is with wrong prediction as 4!
# 	At 305'th: 1 is with wrong prediction as 8!
# 	At 306'th: 8 is with wrong prediction as 0!
# 	At 309'th: 6 is with wrong prediction as 4!
# 	At 312'th: 8 is with wrong prediction as 0!
# 	At 313'th: 0 is with wrong prediction as 2!
# 	At 314'th: 4 is with wrong prediction as 5!
# 	At 318'th: 5 is with wrong prediction as 2!
# 	At 320'th: 3 is with wrong prediction as 5!
# 	At 322'th: 2 is with wrong prediction as 6!
# 	At 323'th: 3 is with wrong prediction as 4!
# 	At 324'th: 4 is with wrong prediction as 5!
# 	At 325'th: 1 is with wrong prediction as 7!
# 	At 326'th: 7 is with wrong prediction as 2!
# 	At 328'th: 4 is with wrong prediction as 0!
# 	At 332'th: 3 is with wrong prediction as 4!
# 	At 334'th: 6 is with wrong prediction as 4!
# 	At 336'th: 3 is with wrong prediction as 6!
# 	At 339'th: 7 is with wrong prediction as 6!
# 	At 340'th: 2 is with wrong prediction as 4!
# 	At 343'th: 5 is with wrong prediction as 0!
# 	At 344'th: 8 is with wrong prediction as 0!
# 	At 346'th: 4 is with wrong prediction as 7!
# 	At 347'th: 6 is with wrong prediction as 5!
# 	At 349'th: 9 is with wrong prediction as 1!
# 	At 350'th: 9 is with wrong prediction as 1!
# 	At 352'th: 0 is with wrong prediction as 8!
# 	At 354'th: 2 is with wrong prediction as 6!
# 	At 356'th: 3 is with wrong prediction as 4!
# 	At 358'th: 8 is with wrong prediction as 1!
# 	At 363'th: 1 is with wrong prediction as 8!
# 	At 364'th: 9 is with wrong prediction as 1!
# 	At 365'th: 4 is with wrong prediction as 0!
# 	At 367'th: 3 is with wrong prediction as 5!
# 	At 368'th: 8 is with wrong prediction as 0!
# 	At 373'th: 4 is with wrong prediction as 2!
# 	At 376'th: 0 is with wrong prediction as 8!
# 	At 378'th: 0 is with wrong prediction as 4!
# 	At 380'th: 6 is with wrong prediction as 4!
# 	At 381'th: 9 is with wrong prediction as 8!
# 	At 383'th: 9 is with wrong prediction as 8!
# 	At 388'th: 2 is with wrong prediction as 5!
# 	At 389'th: 5 is with wrong prediction as 3!
# 	At 391'th: 2 is with wrong prediction as 0!
# 	At 393'th: 2 is with wrong prediction as 5!
# 	At 394'th: 9 is with wrong prediction as 5!
# 	At 396'th: 2 is with wrong prediction as 7!
# 	At 397'th: 3 is with wrong prediction as 5!
# 	At 398'th: 0 is with wrong prediction as 8!
# 	At 399'th: 3 is with wrong prediction as 1!
# 	At 401'th: 8 is with wrong prediction as 1!
# 	At 403'th: 8 is with wrong prediction as 0!
# 	At 404'th: 8 is with wrong prediction as 1!
# 	At 407'th: 1 is with wrong prediction as 9!
# 	At 408'th: 8 is with wrong prediction as 0!
# 	At 409'th: 2 is with wrong prediction as 3!
# 	At 411'th: 9 is with wrong prediction as 8!
# 	At 412'th: 3 is with wrong prediction as 5!
# 	At 415'th: 9 is with wrong prediction as 8!
# 	At 416'th: 0 is with wrong prediction as 7!
# 	At 417'th: 7 is with wrong prediction as 1!
# 	At 418'th: 3 is with wrong prediction as 5!
# 	At 420'th: 4 is with wrong prediction as 6!
# 	At 421'th: 5 is with wrong prediction as 4!
# 	At 422'th: 0 is with wrong prediction as 8!
# 	At 423'th: 0 is with wrong prediction as 5!
# 	At 424'th: 2 is with wrong prediction as 4!
# 	At 425'th: 9 is with wrong prediction as 8!
# 	At 426'th: 3 is with wrong prediction as 5!
# 	At 428'th: 0 is with wrong prediction as 9!
# 	At 430'th: 2 is with wrong prediction as 4!
# 	At 432'th: 3 is with wrong prediction as 5!
# 	At 434'th: 3 is with wrong prediction as 8!
# 	At 435'th: 7 is with wrong prediction as 4!
# 	At 436'th: 2 is with wrong prediction as 5!
# 	At 437'th: 5 is with wrong prediction as 4!
# 	At 438'th: 3 is with wrong prediction as 5!
# 	At 443'th: 9 is with wrong prediction as 8!
# 	At 445'th: 7 is with wrong prediction as 4!
# 	At 446'th: 5 is with wrong prediction as 4!
# 	At 448'th: 2 is with wrong prediction as 4!
# 	At 450'th: 2 is with wrong prediction as 6!
# 	At 451'th: 9 is with wrong prediction as 1!
# 	At 453'th: 3 is with wrong prediction as 5!
# 	At 454'th: 9 is with wrong prediction as 8!
# 	At 455'th: 4 is with wrong prediction as 5!
# 	At 456'th: 3 is with wrong prediction as 4!
# 	At 457'th: 5 is with wrong prediction as 6!
# 	At 458'th: 4 is with wrong prediction as 6!
# 	At 459'th: 6 is with wrong prediction as 9!
# 	At 464'th: 3 is with wrong prediction as 7!
# 	At 465'th: 4 is with wrong prediction as 6!
# 	At 468'th: 7 is with wrong prediction as 5!
# 	At 469'th: 8 is with wrong prediction as 5!
# 	At 470'th: 3 is with wrong prediction as 4!
# 	At 471'th: 7 is with wrong prediction as 3!
# 	At 476'th: 6 is with wrong prediction as 4!
# 	At 477'th: 0 is with wrong prediction as 8!
# 	At 478'th: 5 is with wrong prediction as 2!
# 	At 479'th: 4 is with wrong prediction as 7!
# 	At 480'th: 8 is with wrong prediction as 1!
# 	At 482'th: 8 is with wrong prediction as 0!
# 	At 484'th: 5 is with wrong prediction as 9!
# 	At 486'th: 9 is with wrong prediction as 1!
# 	At 487'th: 9 is with wrong prediction as 1!
# 	At 491'th: 0 is with wrong prediction as 8!
# 	At 492'th: 8 is with wrong prediction as 0!
# 	At 494'th: 1 is with wrong prediction as 8!
# 	At 496'th: 0 is with wrong prediction as 1!
# 	At 498'th: 2 is with wrong prediction as 4!
# 	At 500'th: 4 is with wrong prediction as 6!
# 	At 501'th: 6 is with wrong prediction as 4!
# 	At 504'th: 9 is with wrong prediction as 1!
# 	At 505'th: 4 is with wrong prediction as 2!
# 	At 506'th: 7 is with wrong prediction as 3!
# 	At 507'th: 9 is with wrong prediction as 8!
# 	At 508'th: 9 is with wrong prediction as 8!
# 	At 515'th: 3 is with wrong prediction as 7!
# 	At 517'th: 9 is with wrong prediction as 1!
# 	At 518'th: 5 is with wrong prediction as 7!
# 	At 522'th: 0 is with wrong prediction as 8!
# 	At 524'th: 0 is with wrong prediction as 8!
# 	At 525'th: 5 is with wrong prediction as 6!
# 	At 526'th: 0 is with wrong prediction as 2!
# 	At 528'th: 4 is with wrong prediction as 0!
# 	At 530'th: 9 is with wrong prediction as 8!
# 	At 533'th: 5 is with wrong prediction as 0!
# 	At 537'th: 2 is with wrong prediction as 6!
# 	At 538'th: 9 is with wrong prediction as 8!
# 	At 539'th: 0 is with wrong prediction as 1!
# 	At 545'th: 9 is with wrong prediction as 1!
# 	At 548'th: 2 is with wrong prediction as 6!
# 	At 551'th: 5 is with wrong prediction as 2!
# 	At 554'th: 9 is with wrong prediction as 1!
# 	At 555'th: 4 is with wrong prediction as 0!
# 	At 557'th: 4 is with wrong prediction as 5!
# 	At 558'th: 3 is with wrong prediction as 5!
# 	At 560'th: 0 is with wrong prediction as 8!
# 	At 563'th: 2 is with wrong prediction as 4!
# 	At 564'th: 2 is with wrong prediction as 4!
# 	At 565'th: 3 is with wrong prediction as 5!
# 	At 567'th: 7 is with wrong prediction as 6!
# 	At 569'th: 2 is with wrong prediction as 6!
# 	At 573'th: 3 is with wrong prediction as 1!
# 	At 574'th: 6 is with wrong prediction as 5!
# 	At 575'th: 6 is with wrong prediction as 3!
# 	At 577'th: 9 is with wrong prediction as 0!
# 	At 579'th: 5 is with wrong prediction as 9!
# 	At 582'th: 8 is with wrong prediction as 0!
# 	At 583'th: 4 is with wrong prediction as 5!
# 	At 585'th: 9 is with wrong prediction as 8!
# 	At 586'th: 3 is with wrong prediction as 6!
# 	At 589'th: 9 is with wrong prediction as 1!
# 	At 591'th: 9 is with wrong prediction as 8!
# 	At 592'th: 2 is with wrong prediction as 4!
# 	At 593'th: 6 is with wrong prediction as 4!
# 	At 594'th: 1 is with wrong prediction as 9!
# 	At 595'th: 4 is with wrong prediction as 0!
# 	At 602'th: 0 is with wrong prediction as 8!
# 	At 606'th: 4 is with wrong prediction as 1!
# 	At 607'th: 3 is with wrong prediction as 5!
# 	At 609'th: 9 is with wrong prediction as 1!
# 	At 611'th: 9 is with wrong prediction as 8!
# 	At 614'th: 5 is with wrong prediction as 6!
# 	At 617'th: 6 is with wrong prediction as 7!
# 	At 618'th: 2 is with wrong prediction as 7!
# 	At 624'th: 7 is with wrong prediction as 5!
# 	At 625'th: 9 is with wrong prediction as 1!
# 	At 626'th: 9 is with wrong prediction as 1!
# 	At 629'th: 1 is with wrong prediction as 0!
# 	At 630'th: 2 is with wrong prediction as 8!
# 	At 633'th: 8 is with wrong prediction as 5!
# 	At 634'th: 7 is with wrong prediction as 3!
# 	At 635'th: 6 is with wrong prediction as 3!
# 	At 636'th: 8 is with wrong prediction as 1!
# 	At 637'th: 3 is with wrong prediction as 2!
# 	At 638'th: 0 is with wrong prediction as 8!
# 	At 641'th: 3 is with wrong prediction as 6!
# 	At 642'th: 0 is with wrong prediction as 5!
# 	At 644'th: 9 is with wrong prediction as 8!
# 	At 646'th: 3 is with wrong prediction as 4!
# 	At 647'th: 4 is with wrong prediction as 2!
# 	At 648'th: 4 is with wrong prediction as 2!
# 	At 650'th: 3 is with wrong prediction as 6!
# 	At 652'th: 5 is with wrong prediction as 1!
# 	At 655'th: 2 is with wrong prediction as 0!
# 	At 658'th: 4 is with wrong prediction as 6!
# 	At 663'th: 6 is with wrong prediction as 4!
# 	At 664'th: 3 is with wrong prediction as 5!
# 	At 665'th: 8 is with wrong prediction as 0!
# 	At 667'th: 0 is with wrong prediction as 8!
# 	At 668'th: 1 is with wrong prediction as 9!
# 	At 669'th: 3 is with wrong prediction as 4!
# 	At 671'th: 3 is with wrong prediction as 7!
# 	At 672'th: 6 is with wrong prediction as 7!
# 	At 673'th: 3 is with wrong prediction as 6!
# 	At 674'th: 2 is with wrong prediction as 4!
# 	At 675'th: 0 is with wrong prediction as 8!
# 	At 676'th: 3 is with wrong prediction as 4!
# 	At 677'th: 1 is with wrong prediction as 9!
# 	At 678'th: 0 is with wrong prediction as 5!
# 	At 682'th: 4 is with wrong prediction as 5!
# 	At 683'th: 8 is with wrong prediction as 0!
# 	At 685'th: 6 is with wrong prediction as 4!
# 	At 686'th: 9 is with wrong prediction as 1!
# 	At 687'th: 6 is with wrong prediction as 5!
# 	At 688'th: 3 is with wrong prediction as 6!
# 	At 689'th: 0 is with wrong prediction as 6!
# 	At 690'th: 3 is with wrong prediction as 4!
# 	At 692'th: 2 is with wrong prediction as 0!
# 	At 695'th: 3 is with wrong prediction as 6!
# 	At 697'th: 2 is with wrong prediction as 6!
# 	At 700'th: 7 is with wrong prediction as 9!
# 	At 701'th: 2 is with wrong prediction as 8!
# 	At 703'th: 8 is with wrong prediction as 0!
# 	At 706'th: 2 is with wrong prediction as 8!
# 	At 707'th: 9 is with wrong prediction as 5!
# 	At 710'th: 6 is with wrong prediction as 3!
# 	At 715'th: 3 is with wrong prediction as 6!
# 	At 716'th: 3 is with wrong prediction as 6!
# 	At 717'th: 8 is with wrong prediction as 9!
# 	At 718'th: 4 is with wrong prediction as 2!
# 	At 720'th: 4 is with wrong prediction as 9!
# 	At 722'th: 8 is with wrong prediction as 1!
# 	At 725'th: 2 is with wrong prediction as 5!
# 	At 727'th: 3 is with wrong prediction as 5!
# 	At 729'th: 5 is with wrong prediction as 0!
# 	At 730'th: 4 is with wrong prediction as 5!
# 	At 731'th: 2 is with wrong prediction as 0!
# 	At 732'th: 7 is with wrong prediction as 5!
# 	At 733'th: 9 is with wrong prediction as 6!
# 	At 734'th: 9 is with wrong prediction as 8!
# 	At 736'th: 1 is with wrong prediction as 8!
# 	At 737'th: 4 is with wrong prediction as 0!
# 	At 739'th: 3 is with wrong prediction as 5!
# 	At 740'th: 2 is with wrong prediction as 5!
# 	At 742'th: 0 is with wrong prediction as 9!
# 	At 744'th: 9 is with wrong prediction as 4!
# 	At 746'th: 6 is with wrong prediction as 4!
# 	At 747'th: 6 is with wrong prediction as 3!
# 	At 748'th: 2 is with wrong prediction as 7!
# 	At 750'th: 9 is with wrong prediction as 1!
# 	At 751'th: 2 is with wrong prediction as 0!
# 	At 754'th: 2 is with wrong prediction as 4!
# 	At 761'th: 6 is with wrong prediction as 4!
# 	At 762'th: 6 is with wrong prediction as 3!
# 	At 763'th: 0 is with wrong prediction as 8!
# 	At 764'th: 1 is with wrong prediction as 8!
# 	At 765'th: 2 is with wrong prediction as 4!
# 	At 766'th: 7 is with wrong prediction as 2!
# 	At 767'th: 0 is with wrong prediction as 8!
# 	At 768'th: 5 is with wrong prediction as 7!
# 	At 770'th: 6 is with wrong prediction as 1!
# 	At 771'th: 1 is with wrong prediction as 9!
# 	At 772'th: 6 is with wrong prediction as 5!
# 	At 773'th: 4 is with wrong prediction as 5!
# 	At 775'th: 2 is with wrong prediction as 4!
# 	At 776'th: 2 is with wrong prediction as 7!
# 	At 778'th: 0 is with wrong prediction as 4!
# 	At 779'th: 5 is with wrong prediction as 6!
# 	At 780'th: 9 is with wrong prediction as 1!
# 	At 782'th: 7 is with wrong prediction as 4!
# 	At 786'th: 3 is with wrong prediction as 5!
# 	At 787'th: 9 is with wrong prediction as 8!
# 	At 788'th: 6 is with wrong prediction as 4!
# 	At 790'th: 3 is with wrong prediction as 0!
# 	At 792'th: 3 is with wrong prediction as 5!
# 	At 793'th: 4 is with wrong prediction as 9!
# 	At 795'th: 7 is with wrong prediction as 2!
# 	At 796'th: 1 is with wrong prediction as 5!
# 	At 797'th: 4 is with wrong prediction as 6!
# 	At 798'th: 7 is with wrong prediction as 5!
# 	At 802'th: 4 is with wrong prediction as 2!
# 	At 808'th: 7 is with wrong prediction as 5!
# 	At 809'th: 7 is with wrong prediction as 0!
# 	At 811'th: 3 is with wrong prediction as 6!
# 	At 814'th: 0 is with wrong prediction as 8!
# 	At 816'th: 9 is with wrong prediction as 1!
# 	At 818'th: 8 is with wrong prediction as 1!
# 	At 819'th: 3 is with wrong prediction as 5!
# 	At 820'th: 6 is with wrong prediction as 3!
# 	At 822'th: 0 is with wrong prediction as 8!
# 	At 825'th: 3 is with wrong prediction as 6!
# 	At 826'th: 7 is with wrong prediction as 5!
# 	At 829'th: 3 is with wrong prediction as 0!
# 	At 831'th: 3 is with wrong prediction as 7!
# 	At 833'th: 2 is with wrong prediction as 5!
# 	At 834'th: 5 is with wrong prediction as 4!
# 	At 835'th: 4 is with wrong prediction as 5!
# 	At 836'th: 1 is with wrong prediction as 8!
# 	At 841'th: 0 is with wrong prediction as 8!
# 	At 843'th: 2 is with wrong prediction as 4!
# 	At 845'th: 3 is with wrong prediction as 7!
# 	At 846'th: 2 is with wrong prediction as 4!
# 	At 847'th: 0 is with wrong prediction as 8!
# 	At 848'th: 2 is with wrong prediction as 6!
# 	At 850'th: 7 is with wrong prediction as 5!
# 	At 851'th: 9 is with wrong prediction as 1!
# 	At 853'th: 9 is with wrong prediction as 1!
# 	At 854'th: 0 is with wrong prediction as 8!
# 	At 855'th: 7 is with wrong prediction as 9!
# 	At 859'th: 8 is with wrong prediction as 2!
# 	At 862'th: 3 is with wrong prediction as 6!
# 	At 863'th: 3 is with wrong prediction as 0!
# 	At 866'th: 3 is with wrong prediction as 6!
# 	At 867'th: 7 is with wrong prediction as 5!
# 	At 870'th: 3 is with wrong prediction as 6!
# 	At 873'th: 2 is with wrong prediction as 0!
# 	At 874'th: 3 is with wrong prediction as 5!
# 	At 877'th: 2 is with wrong prediction as 5!
# 	At 878'th: 3 is with wrong prediction as 0!
# 	At 881'th: 4 is with wrong prediction as 5!
# 	At 882'th: 3 is with wrong prediction as 0!
# 	At 883'th: 0 is with wrong prediction as 2!
# 	At 886'th: 0 is with wrong prediction as 9!
# 	At 888'th: 0 is with wrong prediction as 8!
# 	At 890'th: 4 is with wrong prediction as 5!
# 	At 891'th: 6 is with wrong prediction as 4!
# 	At 892'th: 7 is with wrong prediction as 5!
# 	At 893'th: 6 is with wrong prediction as 5!
# 	At 896'th: 3 is with wrong prediction as 7!
# 	At 897'th: 7 is with wrong prediction as 5!
# 	At 901'th: 6 is with wrong prediction as 4!
# 	At 905'th: 7 is with wrong prediction as 2!
# 	At 908'th: 8 is with wrong prediction as 0!
# 	At 910'th: 5 is with wrong prediction as 7!
# 	At 911'th: 3 is with wrong prediction as 5!
# 	At 912'th: 0 is with wrong prediction as 5!
# 	At 913'th: 4 is with wrong prediction as 2!
# 	At 914'th: 0 is with wrong prediction as 7!
# 	At 915'th: 1 is with wrong prediction as 9!
# 	At 916'th: 3 is with wrong prediction as 2!
# 	At 919'th: 0 is with wrong prediction as 4!
# 	At 922'th: 9 is with wrong prediction as 6!
# 	At 924'th: 5 is with wrong prediction as 1!
# 	At 926'th: 8 is with wrong prediction as 9!
# 	At 927'th: 6 is with wrong prediction as 2!
# 	At 929'th: 0 is with wrong prediction as 8!
# 	At 932'th: 3 is with wrong prediction as 5!
# 	At 933'th: 2 is with wrong prediction as 5!
# 	At 935'th: 2 is with wrong prediction as 5!
# 	At 937'th: 5 is with wrong prediction as 7!
# 	At 938'th: 9 is with wrong prediction as 1!
# 	At 940'th: 9 is with wrong prediction as 1!
# 	At 941'th: 1 is with wrong prediction as 7!
# 	At 944'th: 0 is with wrong prediction as 8!
# 	At 945'th: 3 is with wrong prediction as 5!
# 	At 948'th: 3 is with wrong prediction as 5!
# 	At 950'th: 3 is with wrong prediction as 5!
# 	At 951'th: 9 is with wrong prediction as 1!
# 	At 952'th: 6 is with wrong prediction as 4!
# 	At 956'th: 0 is with wrong prediction as 8!
# 	At 957'th: 3 is with wrong prediction as 6!
# 	At 961'th: 1 is with wrong prediction as 5!
# 	At 962'th: 1 is with wrong prediction as 8!
# 	At 965'th: 6 is with wrong prediction as 5!
# 	At 966'th: 6 is with wrong prediction as 9!
# 	At 967'th: 9 is with wrong prediction as 8!
# 	At 970'th: 9 is with wrong prediction as 1!
# 	At 971'th: 4 is with wrong prediction as 6!
# 	At 972'th: 2 is with wrong prediction as 7!
# 	At 974'th: 7 is with wrong prediction as 5!
# 	At 979'th: 9 is with wrong prediction as 1!
# 	At 980'th: 2 is with wrong prediction as 4!
# 	At 981'th: 9 is with wrong prediction as 8!
# 	At 982'th: 0 is with wrong prediction as 5!
# 	At 986'th: 3 is with wrong prediction as 5!
# 	At 988'th: 2 is with wrong prediction as 5!
# 	At 991'th: 5 is with wrong prediction as 3!
# 	At 993'th: 4 is with wrong prediction as 5!
# 	At 995'th: 3 is with wrong prediction as 5!
# 	At 996'th: 8 is with wrong prediction as 0!
# 	At 998'th: 3 is with wrong prediction as 5!

# %%
# Out:
# <module 'tensorflow.keras' from 'c:\\users\\user\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\tensorflow\\keras\\__init__.py'>
